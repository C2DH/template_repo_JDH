# %% [markdown]
# # TitleOfYourArticle

# %% [markdown]
#  ### YourFirstName  YourLastName [![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/ORCID_ID)
# Institution

# %% [markdown]
# ### Contributor2FirstName  Contributor2LastName [![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/ORCID_ID_IF_EXIST)
# Institution

# %% [markdown]
# ### Contributor3FirstName  Contributor3LastName [![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/ORCID_ID_IF_EXIST)
# Institution

# %% [markdown]
# `Below are the two publishing agreements offered by the JDH. Please keep the one which is applicable to your article`.

# %% [markdown]
# [![cc-by](https://licensebuttons.net/l/by/4.0/88x31.png)](https://creativecommons.org/licenses/by/4.0/)
# ©<AUTHOR or ORGANIZATION / FUNDER>. Published by De Gruyter in cooperation with the University of Luxembourg Centre for Contemporary and Digital History. This is an Open Access article distributed under the terms of the [Creative Commons Attribution License CC-BY](https://creativecommons.org/licenses/by/4.0/)

# %% [markdown]
# [![cc-by-nc-nd](https://licensebuttons.net/l/by-nc-nd/4.0/88x31.png)](https://creativecommons.org/licenses/by-nc-nd/4.0/)
# ©<AUTHOR or ORGANIZATION / FUNDER>. Published by De Gruyter in cooperation with the University of Luxembourg Centre for Contemporary and Digital History. This is an Open Access article distributed under the terms of the [Creative Commons Attribution License CC-BY-NC-ND](https://creativecommons.org/licenses/by-nc-nd/4.0/)

# %% [markdown]
# `If including a cover_image`:

# %% [markdown]
# `Below is a code cell explaining the applied metadata for a cover image.`

# %% [markdown]
# `In ordered to be rendered as cover image, the cell should be tagged as "cover":
# Select a cell;
# Open the Property Inspector (right sidebar, gear icon);
# Expand Common Tools → Cell Tags;
# Select the stored tag name "cover" and press Enter or click +`

# %% [markdown]
# `Make sure you add your cover image in the media file of your repository using the label "cover". Title and credits of the image could be inserted in the source field.`

# %%
from IPython.display import Image, display

metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                " ADD YOUR IMAGE TITLE/CAPTION AND ITS SOURCE IF APPLICABLE",
            ]
        }
    }
}

display(Image("media/cover.jpg"), metadata=metadata)

# %% [markdown]
# (This is an optional cell to add if presenting the context or background of your article. It is tagged as `disclaimer`): This article was orginally published (...)

# %% [markdown]
# This is a cell to add your, FirstKeyword, SecondKeyword, AlwaysSeparatedByAComma

# %% [markdown]
# #### Abstract

# %% [markdown]
# This is the abstract cell (...)

# %% [markdown]
# ## Introduction

# %% [markdown]
# There are two **cell types** when using jupyter notebook:
# > *Markdown Cell*: Select when cell contains only narrative text.
#
# > *Code Cell*: Select when when cell contains only Hemeneutics cotent, including, code, image, video, tables, etc.
#
# To learn about Markdown formatting, check this [link](https://www.markdownguide.org/basic-syntax/)
#
# To add, delete and move cells, hover over the selected one and use the small inline toolbar which appears on the right.

# %% [markdown]
# The `Introduction` Section is rendered in a narrative layer. Only Markdown cells should be used. No tags are required. In this section, citations could also be inserted. As an example, we are citing here the JDH article from the Editing team which covers the complete publishing workflow applied to ensure a fully reproducible notebook (<cite id="13poe"><a href="#zotero%7C21707294%2FVSX7U42P">(Clavert et al., 2024)</a></cite>).

# %% [markdown]
# ## FirstSectionName

# %% [markdown]
# To manage citations, the JDH writing environment uses the JupyterLab Citation Manager extension. The plugin is already installed in the requirements.txt file in the repository.

# %% [markdown]
# To use the JupyterLab Citation Manager extension for your citations, you need to :
# - create a Zotero Web API key. You can follow the instructions in this [link](https://www.zotero.org/settings/keys/new).
# - make sure your jupyter notebook is correctly configured to your Zotero key (as shown in [Figure 1](#anchor-figure-zkeysettings).
# - click Insert Citation in the toolbar.
# - search your Zotero library by author, title or year.
# - add your citation inside parentheses within the text.

# %%
from IPython.display import Image, display

metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                " Zotero API settings in Jupyter Notebook",
            ]
        }
    }
}

display(Image("media/zkeysettings.gif"), metadata=metadata)

# %% [markdown]
#  To learn more about how to use and insert citations in your article, check [the following steps](https://journalofdigitalhistory.org/en/guidelines/AuthorGuideline-styling?layer=narrative&idx=51&y=70&pl=narrative&pidx=51&lh=781#:~:text=CAPTION%20HERE%22%0A%5D-,52,-Citation) in our Guidelines for Authors.

# %% [markdown]
# ## SecondSectionName

# %% [markdown]
# JDH uses both python and R libraries. you can check the required library in file runtime.txt.
# When using R code, activate the R kernel.
# For python library, the current version used in the JDH writing enviroment is 3.11.9.
# Run this cell to check your python version:

# %%
from platform import python_version
python_version()
#!python -V
# Out:
# '3.11.9'

# %% [markdown]
# Tags indicate the role of a cell in the article structure (for example title, contributor, figure, or hermeneutics layer). Some tags are already configured in the notebook, others should be added manually. Read this [part](https://journalofdigitalhistory.org/en/guidelines/AuthorGuideline-styling#:~:text=Tags%20in%20JupyterLab-,10,-In%20JupyterLab%2C%20cell) in the guidelines for more information.

# %% [markdown]
# To render the notebook correctly on the JDH website, certain cells must be marked with tags. To learn more about tags and how to apply to properly apply them, check the [Cell tagging](https://journalofdigitalhistory.org/en/guidelines/AuthorGuideline-styling?layer=narrative&idx=5&y=89&pl=narrative&pidx=5&lh=781#:~:text=narrative%20Markdown%20cell.-,6,-Cell%20Tagging) section in our guidelines.

# %% [markdown]
# If using VS code as your editor, you can directly add tags as shown in examples below:: when this is a hermeneutic paragraph, double click on cell, select (+) tag and add `hermeneutics`

# %% [markdown]
# Below is YOURFIRSTTABLE table cell; tag the table as follow: double click on cell, select (+) tag and add `table-yourfirsttable-*`.

# %% [markdown]
# For Markdown table, caption of the table needs to be added manually in the cell metadata. Check this [step](https://journalofdigitalhistory.org/en/guidelines/AuthorGuideline-styling?idx=42&layer=narrative&y=85&pl=narrative&pidx=42&lh=781).

# %% [markdown]
# Editor|1641|1798|1916
# ---|---|---|---
# Senan|0.55|0.4|0.3
# Henry|0.71|0.5|0.63

# %% [markdown]
# If using VS code, open the article.md, look for the following metadata cell for the table and add add the table 1' caption in source   `"jdh": {"module": "object" "object":{ "source": [ "table 1: caption for table 1" ]}}`.

# %% [markdown]
# Long CSV tables need to be added in the script folder of the repository.
# Below is an examlpe of loadded csv table and tagging: table YORUSECONDTABLE to tag as table-yoursecondtable-*

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/college.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/college.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %% [markdown]
# If the table is generated through code, caption of the table needs to be added manually in the cell metadata.

# %% [markdown]
# Pandas package and all python libraries used in the article need to be added to the requirements.txt 's file in the repository.

# %% [markdown]
# Besides images, you can also add sound and video files in your notebook.

# %% [markdown]
# Each image in this file should have a unique label (placeholder).`

# %% [markdown]
# ## YourMethodology

# %% [markdown]
# ## Bibliography
