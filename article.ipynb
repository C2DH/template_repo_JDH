# %% [markdown]
# # Title

# %% [markdown]
#  ### Contributor1FirstName  Contributor1LastName [![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/ORCID_ID)
# Institution

# %% [markdown]
# ### Contributor2FirstName  Contributor2LastName [![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/ORCID_ID_IF_EXIST)
# Institution

# %% [markdown]
# ### Contributor3FirstName  Contributor3LastName [![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/ORCID_ID_IF_EXIST)
# Institution

# %% [markdown]
# [![cc-by](https://licensebuttons.net/l/by/4.0/88x31.png)](https://creativecommons.org/licenses/by/4.0/)
# ©<AUTHOR or ORGANIZATION / FUNDER>. Published by De Gruyter in cooperation with the University of Luxembourg Centre for Contemporary and Digital History. This is an Open Access article distributed under the terms of the [Creative Commons Attribution License CC-BY](https://creativecommons.org/licenses/by/4.0/)

# %% [markdown]
# [![cc-by-nc-nd](https://licensebuttons.net/l/by-nc-nd/4.0/88x31.png)](https://creativecommons.org/licenses/by-nc-nd/4.0/)
# ©<AUTHOR or ORGANIZATION / FUNDER>. Published by De Gruyter in cooperation with the University of Luxembourg Centre for Contemporary and Digital History. This is an Open Access article distributed under the terms of the [Creative Commons Attribution License CC-BY-NC-ND](https://creativecommons.org/licenses/by-nc-nd/4.0/)

# %%
# This is a code cell for cover image. The figure cell is already tagged as "cover". 
# Make sure you add your cover image in the media file of your repository. Each image should have a unique label (placeholder). In this case, the image label is "cover".
# Below is the applied metadata for static image. Replace the source field with the needed information when applicable.

from IPython.display import Image, display

metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                " ADD YOUR IMAGE TITLE/CAPTION AND ITS SOURCE IF APPLICABLE",
            ]
        }
    }
}

display(Image("media/cover.jpg"), metadata=metadata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/display.py:1100, in Image._data_and_metadata(self, always_both)
#    1099 try:
# -> 1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# ...

# %% [markdown]
#  (optional) To present the context or background of your article: This article was orginally published (...)

# %% [markdown]
# Add your FirstKeyword, SecondKeyword, AlwaysSeparatedByAComma

# %% [markdown]
# This is the abstract cell (...)

# %% [markdown]
# ## Introduction

# %% [markdown]
# This is the markdown cell for the Introduction section. It is a narrative section that could include citation examples. Please note that no tag is required in this cell, and it is recommended to not include data or hermenutics elements in this section.
# To learn more about how to use and insert citations in your article, check [the following steps](https://journalofdigitalhistory.org/en/guidelines/AuthorGuideline-styling?layer=narrative&idx=51&y=70&pl=narrative&pidx=51&lh=781#:~:text=CAPTION%20HERE%22%0A%5D-,52,-Citation) in our Guidelines for Authors.

# %% [markdown]
# ## FirstSectionName

# %%
# the python version used in the JDH writing enviroment is python-3.11.9.
# run this cell to check your current python version:

from platform import python_version
python_version()
#!python -V
# Out:
# '3.13.5'

# %% [markdown]
# If section texts include code, images, videos, tables, change the cell type to Code.

# %% [markdown]
# To render the notebook correctly on the JDH website, certain cells must be marked with tags. To learn more about tags and how to apply to properly apply them, check the [Cell tagging](https://journalofdigitalhistory.org/en/guidelines/AuthorGuideline-styling?layer=narrative&idx=5&y=89&pl=narrative&pidx=5&lh=781#:~:text=narrative%20Markdown%20cell.-,6,-Cell%20Tagging) section in our guidelines. Below are examples to follow:

# %% [markdown]
# This is a hermeneutic paragraph

# %% [markdown]
# Editor|1641|1798|1916
# ---|---|---|---
# Senan|0.55|0.4|0.3
# Henry|0.71|0.5|0.63

# %%
# pandas package needs to be added to the requirements.txt 's file 
import pandas as pd

# %% [markdown]
# add pic example of requirements

# %%
# Tables added in script folder
df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/college.csv")
df
# Out:
#                                              Name PredominantDegree  \
# 0                        Alabama A & M University        Bachelor's
# 1             University of Alabama at Birmingham        Bachelor's
# 2             University of Alabama in Huntsville        Bachelor's
# 3                        Alabama State University        Bachelor's
# 4                       The University of Alabama        Bachelor's
# ...                                           ...               ...
# 1289        University of Connecticut-Avery Point        Bachelor's
# 1290           University of Connecticut-Stamford        Bachelor's
# 1291  California State University-Channel Islands        Bachelor's
# 1292              DigiPen Institute of Technology        Bachelor's
# 1293                           Neumont University        Bachelor's
#
#      HighestDegree        FundingModel           Region        Geography  \
# 0         Graduate              Public        Southeast    Mid-size City
# ...

# %% [markdown]
# ## SecondSectionName

# %% [markdown]
# anchors, labels

# %% [markdown]
# ## Bibliography
